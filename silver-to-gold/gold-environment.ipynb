# %% [markdown]
# ## Aeropulse — Gold Environment
#
# **Purpose:** Shared configuration for all gold-layer notebooks. Centralises the silver source paths (airport, carrier, flight) that gold reads from, and the gold dimension paths (origin airport, destination airport, carrier) that `fact-flight` reads back as lookups once they've been built.
#
# **Used by:** `dim-airport` (origin), `dim-airport-destination`, `dim-carrier`, `fact-flight` (via `%run gold-environment`)
#
# **Defines:** `silver_lakehouse_path`, `airport_silver_path`, `carrier_silver_path`, `flight_silver_path`, `airport_origin_path`, `airport_destination_path`, `carrier_path`

# %%
silver_lakehouse_path = "abfss://aeropulse_dev@onelake.dfs.fabric.microsoft.com/aeropulse_silver_lh.Lakehouse/Tables/silver"

airport_silver_path = f"{silver_lakehouse_path}/airport"
carrier_silver_path = f"{silver_lakehouse_path}/carrier"
flight_silver_path = f"{silver_lakehouse_path}/flight"

airport_origin_path = 'abfss://aeropulse_dev@onelake.dfs.fabric.microsoft.com/aeropulse_gold_lh.Lakehouse/Tables/dbo/dim_origin_airport'
airport_destination_path = 'abfss://aeropulse_dev@onelake.dfs.fabric.microsoft.com/aeropulse_gold_lh.Lakehouse/Tables/dbo/dim_destination_airport'
carrier_path = 'abfss://aeropulse_dev@onelake.dfs.fabric.microsoft.com/aeropulse_gold_lh.Lakehouse/Tables/dbo/dim_carrier'
# Out:
# StatementMeta(, , -1, SessionError, , SessionError, True)
# InvalidHttpRequest: [TooManyRequestsForCapacity] [TooManyRequestsForCapacity] HTTP Response code 430: This Spark job can't be run because you've hit spark overall capacity compute limit. To proceed, cancel an active Spark job through the Monitoring hub, choose a larger capacity SKU, or try again later. For more visibility and control, go to Workspace settings → Job management (Job Concurrency & Queue Monitoring) to review running and queued Spark jobs, understand capacity contention, and take action as needed. [Learn more at 'https://go.microsoft.com/fwlink/?linkid=2356970&clcid=0x409']. HTTP status code: 430.
