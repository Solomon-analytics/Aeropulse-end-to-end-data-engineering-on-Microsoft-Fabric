# %% [markdown]
# # Aeropulse - silver environment
#  - purpose: shared configuration for all silver-layer notebooks. Centralises the bronze lakehouse path and the per-source table oaths (airport, carrier, flights) so every silver notebook resolves the same bronze locations without repeating the path string
#  - used by: airport-bronze-to-silver, carrier-bronze-to-silver, flight-bronze-to-silver (via %run silver-environement)

# %%
bronze_lakehouse_path = 'abfss://aeropulse_dev@onelake.dfs.fabric.microsoft.com/aeropulse__bronze__lh.Lakehouse/Tables/dbo/'

airport_bronze_path = f"{bronze_lakehouse_path}/bronze_airport"
carrier_bronze_path = f"{bronze_lakehouse_path}/bronze_carrier"
flight_bronze_path = f"{bronze_lakehouse_path}/bronze_flight"
