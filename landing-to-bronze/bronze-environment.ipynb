# %% [markdown]
# # Bronze Environment Configuration
#
# Shared configuration notebook for the bronze layer — holds the landing lakehouse path and the per-source landing folder locations that bronze notebooks read back from.
#
# - Defines:Landing lakehouse Files path; landing folder paths for airports, carriers, and flights
# - Used by: "flight-landing-to-bronze", "airport-landing-to-bronze", "carrier-landing-to-bronze" (via `%run`)

# %%
landing_lakehouse_path = 'abfss://aeropulse_dev@onelake.dfs.fabric.microsoft.com/aeropulse_landing_lh.Lakehouse/Files'

airport_landing_path = f"{landing_lakehouse_path}/airport"
carrier_landing_path = f"{landing_lakehouse_path}/carrier"
flight_landing_path = f"{landing_lakehouse_path}/flights/{batch_id}"
